# %% [markdown]
# # Line and Area Charts

# %% [markdown]
# ## **Excel:**
#
# *   Created from ribbon: Insert -> Charts
#
# ![line_area_charts.png](data:image/png;base64,...)

# %% [markdown]
# ## **Python:**
#
#
#
# *   Uses matplotlib.pyplot package
#
# <br>
#
# **Line plot:**
#
#
#     plt.plot('x_column', 'y_column', data=df)
#     plt.title('Title')
#     plt.xlabel('X Label')
#     plt.ylabel('Y Label')
#     plt.show()
#
# **Area plot:**
#
#     plt.stackplot('x_column', 'y_column', data=df)
#     plt.title('Title')
#     plt.xlabel('X Label')
#     plt.ylabel('Y Label')
#     plt.show()
#
# <br>

# %% [markdown]
# ### Load required packages and data
# ---

# %%
# Import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from vega_datasets import data
stock_data = data.sp500()

# %% [markdown]
# <br>
#
# ### Example: Line Chart
# ---

# %%
# View the S&P 5000 "stock_data"
stock_data.head()
# Out:
#         date    price
# 0 2000-01-01  1394.46
# 1 2000-02-01  1366.42
# 2 2000-03-01  1498.58
# 3 2000-04-01  1452.43
# 4 2000-05-01  1420.60

# %% [markdown]
# <br>

# %%
# Build a line chart of the "stock_data"
plt.plot('date', 'price', data=stock_data)
plt.show()

# %% [markdown]
# <br>

# %%
# Add title and labels to chart
plt.plot('date', 'price', data=stock_data)
plt.title('S&P 500 Index')
plt.xlabel('Year')
plt.ylabel('Index')
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# <br>
#
# ### Example: Area chart
# ---

# %%
# Build an area chart using "stock_data"
plt.stackplot('date', 'price', data=stock_data)
plt.title('S&P 500 Index')
plt.xlabel('Year')
plt.ylabel('Index')
plt.show()

# %% [markdown]
# <br><br>
# **QUICK CHALLENGE #1:**
#
# You are tasked with creating a chart which shows the employment numbers in the mining and logging industry.
#
# **Task:**
#
# *  Use the `mining_and_logging` column in the `employment_data` dataframe from to build a line plot **OR** shaded area chart.
# *  Include an appropriate title and labels

# %%
# Create the data, convert month to date type, and preview
employment_data = data.us_employment()
employment_data['month'] = pd.to_datetime(employment_data['month'])
employment_data.head()
# Out:
#        month  nonfarm  private  ...  other_services  government  nonfarm_change
# 0 2006-01-01   135450   113603  ...            5425       21847             282
# 1 2006-02-01   135762   113884  ...            5426       21878             312
# 2 2006-03-01   136059   114156  ...            5425       21903             297
# 3 2006-04-01   136227   114308  ...            5426       21919             168
# 4 2006-05-01   136258   114332  ...            5433       21926              31
#
# [5 rows x 24 columns]

# %% [markdown]
# <br>

# %%
# Your code for quick challenge #1 here:
plt.stackplot('month', 'mining_and_logging', data=employment_data)
plt.title('Mining and Logging Employment')
plt.xlabel('Year')
plt.ylabel('Employment')
plt.show()

# %%
/
