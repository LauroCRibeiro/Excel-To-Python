# %% [markdown]
# # Appending Data
# ---

# %% [markdown]
# ## **Excel:**
#
# *   Copy and paste new data below existing
# *   Use Power Query to append

# %% [markdown]
# ## **Python:**
#
#
#
# *   Use pd.concat()
#
#
#     pd.concat([df1, df2], axis=0)
#
#
# ![axis-example.png](data:image/png;base64,...)
#
# <br>

# %% [markdown]
# <br>
#
# ### Load required packages and data
# ---

# %%
# Import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Save Github location paths to a variable
failed_bank_path = 'https://github.com/The-Calculated-Life/python_analysis_for_excel/blob/main/data/failed_banks.xlsx?raw=true'
bx_books_path = 'https://raw.githubusercontent.com/The-Calculated-Life/python_analysis_for_excel/main/data/bx_books.csv'

# Read excel and CSV files
bank_list = pd.read_excel(failed_bank_path, sheet_name='banks')
bx_books = pd.read_csv(bx_books_path)

# Create split dataframes 
failed_banks_before_2010 = bank_list[bank_list['Closing Date'] <= '2010-12-31']
failed_banks_after_2010 = bank_list[bank_list['Closing Date'] > '2010-12-31']
bx_books_before_2000 = bx_books[bx_books['year_of_publication'] < 2000]
bx_books_after_2000 = bx_books[bx_books['year_of_publication'] >= 2000]

# %% [markdown]
# <br><br>
#
# ### Example: Appending data
# ---

# %%
# View failed_banks_before_2010
failed_banks_before_2010.head()
# Out:
#       CERT  ... Closing Date
# 212  23306  ...   2010-12-17
# 213  58052  ...   2010-12-17
# 214  35065  ...   2010-12-17
# 215  58495  ...   2010-12-17
# 216  34578  ...   2010-12-17
#
# [5 rows x 6 columns]

# %% [markdown]
# <br>

# %%
# View the number of rows in "failed_banks_before_2010"
failed_banks_before_2010.shape[0]
# Out:
# 349

# %% [markdown]
# <br>

# %%
# View failed_banks_after_2010
failed_banks_after_2010.head()
# Out:
#     CERT  ... Closing Date
# 0  14361  ...   2020-04-03
# 1  18265  ...   2020-02-14
# 2  21111  ...   2019-11-01
# 3  58317  ...   2019-10-25
# 4  58112  ...   2019-10-25
#
# [5 rows x 6 columns]

# %% [markdown]
# <br>

# %%
# View the number of rows in "failed_banks_after_2010"
failed_banks_after_2010.shape[0]
# Out:
# 212

# %% [markdown]
# <br>

# %%
# Add the number of rows together to see how many rows the resulting dataframe should have
failed_banks_before_2010.shape[0] + failed_banks_after_2010.shape[0]
# Out:
# 561

# %% [markdown]
# <br>

# %%
# Append the two dataframes
pd.concat([failed_banks_before_2010, failed_banks_after_2010], axis=0)
# Out:
#       CERT  ... Closing Date
# 212  23306  ...   2010-12-17
# 213  58052  ...   2010-12-17
# 214  35065  ...   2010-12-17
# 215  58495  ...   2010-12-17
# 216  34578  ...   2010-12-17
# ..     ...  ...          ...
# 207  57868  ...   2011-01-21
# 208  19758  ...   2011-01-21
# 209  57440  ...   2011-01-14
# 210  57820  ...   2011-01-07
# 211  34965  ...   2011-01-07
#
# [561 rows x 6 columns]

# %% [markdown]
# <br>

# %% [markdown]
# <br><br>
# **QUICK CHALLENGE #1:**
#
# **Task: Use pd.concat() to append `bx_books_before_2000` and `bx_books_after_2000`**

# %%
# Your code for quick challenge #1 here:
pd.concat([bx_books_before_2000, bx_books_after_2000], axis=0)
# Out:
#               isbn  ...                                         publisher
# 2         60973129  ...                                   HarperPerennial
# 3        374157065  ...                              Farrar Straus Giroux
# 4        393045218  ...                        W. W. Norton &amp; Company
# 5        399135782  ...                                  Putnam Pub Group
# 7        671870432  ...                                        Audioworks
# ...            ...  ...                                               ...
# 271369   762412119  ...                     Running Press Book Publishers
# 271370  1582380805  ...             Golden Guides from St. Martin's Press
# 271371  1845170423  ...                                         Connaught
# 271376  006008667X  ...                                HarperSanFrancisco
# 271378   767409752  ...  McGraw-Hill Humanities/Social Sciences/Languages
#
# [271379 rows x 5 columns]
